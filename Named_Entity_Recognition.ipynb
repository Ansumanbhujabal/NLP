# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.chunk import ne_chunk
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
sentences=""" I, Ansuman SSB would like to extend my sincere apologies for any inconvenience or disruptions that may have occurred during the recent study tour. We understand that unexpected situations can sometimes arise, and we appreciate your patience and understanding as we navigated these challenges.Your cooperation and flexibility have been invaluable in ensuring the success of the tour despite these hurdles. I am genuinely grateful for your support and willingness to adjust as needed.Thank you once again for your understanding and for making the study tour a valuable experience.
"""

# %%
ne_chunk(pos_tag(word_tokenize(sentences)))
# Out:
# Tree('S', [('I', 'PRP'), (',', ','), Tree('PERSON', [('Ansuman', 'NNP'), ('SSB', 'NNP')]), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('extend', 'VB'), ('my', 'PRP$'), ('sincere', 'JJ'), ('apologies', 'NNS'), ('for', 'IN'), ('any', 'DT'), ('inconvenience', 'NN'), ('or', 'CC'), ('disruptions', 'NNS'), ('that', 'WDT'), ('may', 'MD'), ('have', 'VB'), ('occurred', 'VBN'), ('during', 'IN'), ('the', 'DT'), ('recent', 'JJ'), ('study', 'NN'), ('tour', 'NN'), ('.', '.'), ('We', 'PRP'), ('understand', 'VBP'), ('that', 'IN'), ('unexpected', 'JJ'), ('situations', 'NNS'), ('can', 'MD'), ('sometimes', 'RB'), ('arise', 'VB'), (',', ','), ('and', 'CC'), ('we', 'PRP'), ('appreciate', 'VBP'), ('your', 'PRP$'), ('patience', 'NN'), ('and', 'CC'), ('understanding', 'JJ'), ('as', 'IN'), ('we', 'PRP'), ('navigated', 'VBD'), ('these', 'DT'), ('challenges.Your', 'JJ'), ('cooperation', 'NN'), ('and', 'CC'), ('flexibility', 'NN'), ('have', 'VBP'), ('been', 'VBN'), ('invaluable', 'JJ'), ('in', 'IN'), ('ensu
# ...
